# %% [markdown]
# ## Author - Vinayak Vaidyanathan

# %% [markdown]
# ## Importing Required Libraries and Loading Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

file = r"C:\Users\Vinayak Vaidyanathan\Downloads\cubic_zirconia.csv\cubic_zirconia.csv"
df = pd.read_csv(file, index_col =0)
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779

# %% [markdown]
# ## Exploring the Data

# %%
df.shape
# Out:
# (26967, 10)

# %%
df.isnull().sum()
# Out:
# carat        0
# cut          0
# color        0
# clarity      0
# depth      697
# table        0
# x            0
# y            0
# z            0
# price        0
# dtype: int64

# %%
df1 = df.dropna()
df1
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 1       0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 2       0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 3       0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 4       0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 5       0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 26963   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52  4.09   5408
# 26964   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42  2.74   1114
# 26965   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15  3.17   1656
# 26966   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20  2.60    682
# 26967   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88  4.27   5166
#
# [26270 rows x 10 columns]

# %%
dup = df1.duplicated()
print('Number of duplicate rows = %d' % (dup.sum()))
print(df1.shape)
# Out:
# Number of duplicate rows = 34
# (26270, 10)

# %%
df1.drop_duplicates(inplace=True)

# %%
df1.info
# Out:
# <bound method DataFrame.info of        carat        cut color clarity  depth  table     x     y     z  price
# 1       0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 2       0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 3       0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 4       0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 5       0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 26963   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52  4.09   5408
# 26964   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42  2.74   1114
# 26965   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15  3.17   1656
# 26966   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20  2.60    682
# 26967   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88  4.27   5166
#
# ...

# %%
df1.describe()
# Out:
#               carat         depth         table             x             y  \
# count  26236.000000  26236.000000  26236.000000  26236.000000  26236.000000
# mean       0.797620     61.745285     57.455877      5.728646      5.732487
# std        0.476691      1.412243      2.230866      1.126332      1.165283
# min        0.200000     50.800000     49.000000      0.000000      0.000000
# 25%        0.400000     61.000000     56.000000      4.710000      4.720000
# 50%        0.700000     61.800000     57.000000      5.690000      5.700000
# 75%        1.050000     62.500000     59.000000      6.540000      6.540000
# max        4.500000     73.600000     79.000000     10.230000     58.900000
#
#                   z         price
# count  26236.000000  26236.000000
# mean       3.536339   3935.926818
# std        0.698608   4019.809223
# min        0.000000    326.000000
# 25%        2.900000    945.000000
# 50%        3.520000   2374.000000
# 75%        4.040000   5356.000000
# ...

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ## 1. Uni-Variate Analysis
# (Analysis Involving Single Variable)

# %%
fig, axs= plt.subplots(nrows=2,ncols=2,figsize=(10,10))

sns.countplot(df['carat'],ax=axs[0][0])
sns.countplot(df['depth'],ax=axs[0][1])
sns.countplot(df['table'],ax=axs[1][0])
sns.countplot(df['price'],ax=axs[1][1])

axs[0][0].set_title('carat')
axs[0][1].set_title('depth')
axs[1][0].set_title('table')
axs[1][1].set_title('price')
# Out:
# C:\Users\Vinayak Vaidyanathan\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Vinayak Vaidyanathan\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
df1.hist(figsize=(20,30));

# %%
df1.skew()
# Out:
# C:\Users\VINAYA~1\AppData\Local\Temp/ipykernel_19272/3620588158.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.skew()
# carat    1.116003
# depth   -0.026086
# table    0.768777
# x        0.391761
# y        3.957907
# z        0.368700
# price    1.620621
# dtype: float64

# %% [markdown]
# There is significant amount of outlier present in some variable. We can see that the distribution of some quantitative features like "carat" and the target feature "price" are heavily "right-skewed".

# %% [markdown]
# ## 2. Bivariate Analysis

# %%
sdf_attr = ( df1[cols])
sns.pairplot(sdf_attr, diag_kind='kde')  
plt.show()

# %% [markdown]
# ## Corelation Heatmap

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(np.round(df1.corr(),2), annot=True,ax=ax)
# Out:
# <AxesSubplot:>

# %%
correlations = df1.corr()
correlations["price"].sort_values(ascending=False)
# Out:
# price    1.000000
# carat    0.922125
# x        0.886305
# z        0.876469
# y        0.855365
# table    0.126485
# depth   -0.002895
# Name: price, dtype: float64

# %% [markdown]
# It can be inferred that most features correlate with the price of Diamond. The notable exception is "depth" which has a negligible correlation (<1%).

# %% [markdown]
# ## Exploratory Analysis of categorical variable

# %%
sns.catplot('cut', data=df1, kind='count',aspect=2.5)
# Out:
# C:\Users\Vinayak Vaidyanathan\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot(x='cut', y='price', kind='box', data=df1, aspect=2.5)

# %% [markdown]
# The Premium Cut on Diamonds are the most Expensive, followed by Very Good Cut.

# %%
sns.catplot('color', kind='count', data=df1, aspect=2.5)
# Out:
# C:\Users\Vinayak Vaidyanathan\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot(x='color', y='price', data=df1, aspect =2.5, kind='box')

# %% [markdown]
# The Diamonds clarity with VS1 & VS2 are the most Expensive.
